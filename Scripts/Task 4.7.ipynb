# %% [markdown]
# # Exercise 4.7

# %% [markdown]
# ## Script Contents:
#
# Part 1: Exercise
#
# Part 2: Task
#
# 1. Import libraries
# 2. Create 'busiest days' variable
# 3. Create 'busiest_period_of_day' variable
# 4. Print the frequency for the new variable
# 5. Change column name for clarity before exporting
# 6. Export the dataset

# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#Create a path
path = r'C:\Users\dyl41\Documents\11-14-2022 Instacart Basket Analysis'

# %%
#Import ords_prods_merged
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#Limit the dataframe to the first million rows
df = df_ords_prods_merged[:1000000]

# %%
#Check the new dataframe condition
df
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2398795        1             2                   3
# 2         473747        1             3                   3
# 3        2254736        1             4                   4
# 4         431534        1             5                   4
# ...          ...      ...           ...                 ...
# 999995   2836489   164627            14                   0
# 999996   1843600   164632             5                   1
# 999997    733106   164632             9                   2
# 999998   1650124   164632            17                   6
# 999999   3378258   164632            22                   6
#
#         order_hour_of_day  days_since_prior_order  first_purchase  product_id  \
# 0                       8                     NaN            True         196
# 1                       7                    15.0           False         196
# ...

# %%
#Create user defined condition
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#Define the string function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\dyl41\AppData\Local\Temp\ipykernel_15004\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
#Check the subset using the price_range function
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#Check the max value of the subset
df['prices'].max()
# Out:
# 14.8

# %%
#Define the string function using loc
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Check the value counts of string function using loc
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#Define the string function using loc of the whole dataframe
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Check the value counts of string function on the whole dataframe
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
#Check which days of the week have highest/lowest order counts
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
#Use for loop to create a result set
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
#Check output of for loop result
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#Combine the for loop with the dataframe
df_ords_prods_merged['Busiest day'] = result

# %%
#Check for loop against dataframe
df_ords_prods_merged['Busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest day, dtype: int64

# %% [markdown]
# # Task 4.7

# %% [markdown]
# ## Question 1

# %%
#Change column title for clarity
df_ords_prods_merged.rename(columns = {'busiest days':'busiest_days'}, inplace = True)

# %%
#Recheck busiest/slowest days
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  first_purchase  \
# 0                         8                     NaN            True
# 1                         7                    15.0           False
# ...

# %%
#Define result2 set
result2 = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value in [0,1]:
    result2.append("Busiest day")
  elif value in [3,4]:
    result2.append("Least busy")
  else:
    result2.append("Regularly busy")

# %%
#Merge dataframe with result2
df_ords_prods_merged['busiest_days'] = result2

# %%
#Check new column
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  first_purchase  \
# 0                         8                     NaN            True
# 1                         7                    15.0           False
# ...

# %% [markdown]
# ## Question 2

# %%
#Check result set length
len(result2)
# Out:
# 32404859

# %%
#Check and compare to orders_day_of_week column
df_ords_prods_merged['orders_day_of_week'].shape
# Out:
# (32404859,)

# %%
#Check the value counts
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest day       11864412
# Least busy         7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# ## Question 3

# %%
#Check the frequency of the orders by hour
label_counts = df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)

# %%
label_counts
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# There are 24 hours of orders in a day and three time periods requested for the analysis (fewest, average, most). I took 24 and divided by 3, so the top 8 are most, the middle 8 are average, and the bottom 8 are fewest.

# %%
#Define result3 set
result3 = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in [9,10,11,12,13,14,15,16]:
    result3.append("Most orders")
  elif value in [7,8,17,18,19,20,21,22]:
    result3.append("Average orders")
  elif value in [0,1,2,3,4,5,6,23]:
    result3.append("Fewest orders")

# %%
#Merge result3 with the dataframe to create new column
df_ords_prods_merged['busiest_period_of_day'] = result3

# %%
#Check the dataframe
df_ords_prods_merged.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order  first_purchase  product_id  add_to_cart_order  \
# 0                     NaN            True         196                  1
# ...

# %%
#Check the frequency values of the new column
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %%
#Change column name for clarity before exporting
df_ords_prods_merged.rename(columns = {'price_range_loc':'prod_price_range'}, inplace = True)

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  first_purchase  \
# 0                         8                     NaN            True
# 1                         7                    15.0           False
# ...

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_update.pkl'))
